# %%
import importlib
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

import matplotlib.pyplot as plt

# %%
import classes, utils, iv_models, svi_class
_ = importlib.reload(classes)
_ = importlib.reload(utils)
_ = importlib.reload(iv_models)
_ = importlib.reload(svi_class)

from classes import Ticker, TickerSet, OptionChain
from utils import get_errors_for_models
from iv_models import IVPolynomial, SVIModel, kernel_smoothening
from svi_class import SVIClass

# %%
ts = TickerSet("20210805 15:15:00", "20210806 10:00:00")#, tickers=['INDHOTEL', 'INDIGO', 'INDUSINDBK', 'INDUSTOWER', 'INFY', 'IOC'])
# ts = TickerSet("20210805 15:15:00", "20210806 10:00:00", tickers=['HDFCBANK'])
# ts = TickerSet("20210805 15:15:00", "20210806 10:00:00", tickers=['RELIANCE', 'INDHOTEL', 'INDIGO', 'INDUSINDBK', 'INDUSTOWER', 'INFY', 'IOC'])
# Out:
# globbing ./data/*/*_AARTIIND21AUG*.csv
# loading data from ./data/20210805/influxOP_AARTIIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AARTIIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ABFRL21AUG*.csv
# loading data from ./data/20210811/influxOP_ABFRL21AUG_20210811.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210805/influxOP_ABFRL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ABFRL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ACC21AUG*.csv
# loading data from ./data/20210805/influxOP_ACC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ACC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ADANIENT21AUG*.csv
# loading data from ./data/20210805/influxOP_ADANIENT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ADANIENT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ADANIPORTS21AUG*.csv
# loading data from ./data/20210805/influxOP_ADANIPORTS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ADANIPORTS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ALKEM21AUG*.csv
# loading data from ./data/20210805/influxOP_ALKEM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ALKEM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_AMARAJABAT21AUG*.csv
# loading data from ./data/20210805/influxOP_AMARAJABAT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AMARAJABAT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_AMBUJACEM21AUG*.csv
# loading data from ./data/20210805/influxOP_AMBUJACEM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AMBUJACEM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_APLLTD21AUG*.csv
# loading data from ./data/20210805/influxOP_APLLTD21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_APLLTD21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_APOLLOHOSP21AUG*.csv
# loading data from ./data/20210805/influxOP_APOLLOHOSP21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_APOLLOHOSP21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_APOLLOTYRE21AUG*.csv
# loading data from ./data/20210805/influxOP_APOLLOTYRE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_APOLLOTYRE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ASHOKLEY21AUG*.csv
# loading data from ./data/20210805/influxOP_ASHOKLEY21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ASHOKLEY21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ASIANPAINT21AUG*.csv
# loading data from ./data/20210805/influxOP_ASIANPAINT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ASIANPAINT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ASTRAL21AUG*.csv
# loading data from ./data/20210805/influxOP_ASTRAL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ASTRAL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_AUBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_AUBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AUBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_AUROPHARMA21AUG*.csv
# loading data from ./data/20210805/influxOP_AUROPHARMA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AUROPHARMA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_AXISBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_AXISBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_AXISBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BAJAJFINSV21AUG*.csv
# loading data from ./data/20210805/influxOP_BAJAJFINSV21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BAJAJFINSV21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BAJAJ_AUTO21AUG*.csv
# loading data from ./data/20210805/influxOP_BAJAJ_AUTO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BAJAJ_AUTO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BAJFINANCE21AUG*.csv
# loading data from ./data/20210805/influxOP_BAJFINANCE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BAJFINANCE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BALKRISIND21AUG*.csv
# loading data from ./data/20210805/influxOP_BALKRISIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BALKRISIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BANDHANBNK21AUG*.csv
# loading data from ./data/20210805/influxOP_BANDHANBNK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BANDHANBNK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BANKBARODA21AUG*.csv
# loading data from ./data/20210805/influxOP_BANKBARODA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BANKBARODA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BATAINDIA21AUG*.csv
# loading data from ./data/20210805/influxOP_BATAINDIA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BATAINDIA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BEL21AUG*.csv
# loading data from ./data/20210805/influxOP_BEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BERGEPAINT21AUG*.csv
# loading data from ./data/20210805/influxOP_BERGEPAINT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BERGEPAINT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BHARATFORG21AUG*.csv
# loading data from ./data/20210805/influxOP_BHARATFORG21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BHARATFORG21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BHARTIARTL21AUG*.csv
# loading data from ./data/20210805/influxOP_BHARTIARTL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BHARTIARTL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BHEL21AUG*.csv
# loading data from ./data/20210805/influxOP_BHEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BHEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BIOCON21AUG*.csv
# loading data from ./data/20210805/influxOP_BIOCON21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BIOCON21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BOSCHLTD21AUG*.csv
# loading data from ./data/20210805/influxOP_BOSCHLTD21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BOSCHLTD21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BPCL21AUG*.csv
# loading data from ./data/20210805/influxOP_BPCL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BPCL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_BRITANNIA21AUG*.csv
# loading data from ./data/20210805/influxOP_BRITANNIA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_BRITANNIA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CADILAHC21AUG*.csv
# loading data from ./data/20210805/influxOP_CADILAHC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CADILAHC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CANBK21AUG*.csv
# loading data from ./data/20210805/influxOP_CANBK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CANBK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CHOLAFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_CHOLAFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CHOLAFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CIPLA21AUG*.csv
# loading data from ./data/20210805/influxOP_CIPLA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CIPLA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_COALINDIA21AUG*.csv
# loading data from ./data/20210805/influxOP_COALINDIA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_COALINDIA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_COFORGE21AUG*.csv
# loading data from ./data/20210805/influxOP_COFORGE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_COFORGE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_COLPAL21AUG*.csv
# loading data from ./data/20210805/influxOP_COLPAL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_COLPAL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CONCOR21AUG*.csv
# loading data from ./data/20210805/influxOP_CONCOR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CONCOR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_COROMANDEL21AUG*.csv
# loading data from ./data/20210805/influxOP_COROMANDEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_COROMANDEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CUB21AUG*.csv
# loading data from ./data/20210805/influxOP_CUB21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CUB21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_CUMMINSIND21AUG*.csv
# loading data from ./data/20210805/influxOP_CUMMINSIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_CUMMINSIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_DABUR21AUG*.csv
# loading data from ./data/20210805/influxOP_DABUR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_DABUR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_DEEPAKNTR21AUG*.csv
# loading data from ./data/20210805/influxOP_DEEPAKNTR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_DEEPAKNTR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_DIVISLAB21AUG*.csv
# loading data from ./data/20210805/influxOP_DIVISLAB21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_DIVISLAB21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_DLF21AUG*.csv
# loading data from ./data/20210805/influxOP_DLF21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_DLF21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_DRREDDY21AUG*.csv
# loading data from ./data/20210805/influxOP_DRREDDY21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_DRREDDY21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_EICHERMOT21AUG*.csv
# loading data from ./data/20210805/influxOP_EICHERMOT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_EICHERMOT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ESCORTS21AUG*.csv
# loading data from ./data/20210805/influxOP_ESCORTS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ESCORTS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_EXIDEIND21AUG*.csv
# loading data from ./data/20210805/influxOP_EXIDEIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_EXIDEIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_FEDERALBNK21AUG*.csv
# loading data from ./data/20210805/influxOP_FEDERALBNK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_FEDERALBNK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GAIL21AUG*.csv
# loading data from ./data/20210805/influxOP_GAIL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GAIL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GLENMARK21AUG*.csv
# loading data from ./data/20210805/influxOP_GLENMARK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GLENMARK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GMRINFRA21AUG*.csv
# loading data from ./data/20210805/influxOP_GMRINFRA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GMRINFRA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GODREJCP21AUG*.csv
# loading data from ./data/20210805/influxOP_GODREJCP21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GODREJCP21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GODREJPROP21AUG*.csv
# loading data from ./data/20210805/influxOP_GODREJPROP21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GODREJPROP21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GRANULES21AUG*.csv
# loading data from ./data/20210805/influxOP_GRANULES21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GRANULES21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GRASIM21AUG*.csv
# loading data from ./data/20210805/influxOP_GRASIM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GRASIM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_GUJGASLTD21AUG*.csv
# loading data from ./data/20210805/influxOP_GUJGASLTD21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_GUJGASLTD21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HAVELLS21AUG*.csv
# loading data from ./data/20210805/influxOP_HAVELLS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HAVELLS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HCLTECH21AUG*.csv
# loading data from ./data/20210805/influxOP_HCLTECH21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HCLTECH21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HDFC21AUG*.csv
# loading data from ./data/20210805/influxOP_HDFC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HDFC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HDFCAMC21AUG*.csv
# loading data from ./data/20210805/influxOP_HDFCAMC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HDFCAMC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HDFCBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_HDFCBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HDFCBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HDFCLIFE21AUG*.csv
# loading data from ./data/20210805/influxOP_HDFCLIFE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HDFCLIFE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HEROMOTOCO21AUG*.csv
# loading data from ./data/20210805/influxOP_HEROMOTOCO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HEROMOTOCO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HINDALCO21AUG*.csv
# loading data from ./data/20210805/influxOP_HINDALCO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HINDALCO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HINDPETRO21AUG*.csv
# loading data from ./data/20210805/influxOP_HINDPETRO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HINDPETRO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_HINDUNILVR21AUG*.csv
# loading data from ./data/20210805/influxOP_HINDUNILVR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_HINDUNILVR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_IBULHSGFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_IBULHSGFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IBULHSGFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ICICIBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_ICICIBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ICICIBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ICICIGI21AUG*.csv
# loading data from ./data/20210805/influxOP_ICICIGI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ICICIGI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ICICIPRULI21AUG*.csv
# loading data from ./data/20210805/influxOP_ICICIPRULI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ICICIPRULI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_IDEA21AUG*.csv
# loading data from ./data/20210805/influxOP_IDEA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IDEA21AUG_20210806.csv
# 2021-08-26 20:00:00
# skipped IDEA
# globbing ./data/*/*_IDFCFIRSTB21AUG*.csv
# loading data from ./data/20210805/influxOP_IDFCFIRSTB21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IDFCFIRSTB21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_IGL21AUG*.csv
# loading data from ./data/20210805/influxOP_IGL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IGL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_INDHOTEL21AUG*.csv
# loading data from ./data/20210805/influxOP_INDHOTEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_INDHOTEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_INDIGO21AUG*.csv
# loading data from ./data/20210805/influxOP_INDIGO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_INDIGO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_INDUSINDBK21AUG*.csv
# loading data from ./data/20210805/influxOP_INDUSINDBK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_INDUSINDBK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_INDUSTOWER21AUG*.csv
# loading data from ./data/20210805/influxOP_INDUSTOWER21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_INDUSTOWER21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_INFY21AUG*.csv
# loading data from ./data/20210805/influxOP_INFY21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_INFY21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_IOC21AUG*.csv
# loading data from ./data/20210805/influxOP_IOC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IOC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_IRCTC21AUG*.csv
# loading data from ./data/20210805/influxOP_IRCTC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_IRCTC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ITC21AUG*.csv
# loading data from ./data/20210805/influxOP_ITC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ITC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_JINDALSTEL21AUG*.csv
# loading data from ./data/20210805/influxOP_JINDALSTEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_JINDALSTEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_JSWSTEEL21AUG*.csv
# loading data from ./data/20210805/influxOP_JSWSTEEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_JSWSTEEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_JUBLFOOD21AUG*.csv
# loading data from ./data/20210805/influxOP_JUBLFOOD21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_JUBLFOOD21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_KOTAKBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_KOTAKBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_KOTAKBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LALPATHLAB21AUG*.csv
# loading data from ./data/20210805/influxOP_LALPATHLAB21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LALPATHLAB21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LICHSGFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_LICHSGFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LICHSGFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LT21AUG*.csv
# loading data from ./data/20210805/influxOP_LT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LTI21AUG*.csv
# loading data from ./data/20210805/influxOP_LTI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LTI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LTTS21AUG*.csv
# loading data from ./data/20210805/influxOP_LTTS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LTTS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_LUPIN21AUG*.csv
# loading data from ./data/20210805/influxOP_LUPIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_LUPIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_L_TFH21AUG*.csv
# loading data from ./data/20210805/influxOP_L_TFH21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_L_TFH21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MANAPPURAM21AUG*.csv
# loading data from ./data/20210805/influxOP_MANAPPURAM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MANAPPURAM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MARICO21AUG*.csv
# loading data from ./data/20210805/influxOP_MARICO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MARICO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MARUTI21AUG*.csv
# loading data from ./data/20210805/influxOP_MARUTI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MARUTI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MCDOWELL_N21AUG*.csv
# loading data from ./data/20210805/influxOP_MCDOWELL_N21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MCDOWELL_N21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_METROPOLIS21AUG*.csv
# loading data from ./data/20210805/influxOP_METROPOLIS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_METROPOLIS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MFSL21AUG*.csv
# loading data from ./data/20210805/influxOP_MFSL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MFSL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MGL21AUG*.csv
# loading data from ./data/20210805/influxOP_MGL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MGL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MINDTREE21AUG*.csv
# loading data from ./data/20210805/influxOP_MINDTREE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MINDTREE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MOTHERSUMI21AUG*.csv
# loading data from ./data/20210805/influxOP_MOTHERSUMI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MOTHERSUMI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MPHASIS21AUG*.csv
# loading data from ./data/20210805/influxOP_MPHASIS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MPHASIS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MRF21AUG*.csv
# loading data from ./data/20210805/influxOP_MRF21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MRF21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_MUTHOOTFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_MUTHOOTFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_MUTHOOTFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_M_M21AUG*.csv
# loading data from ./data/20210805/influxOP_M_M21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_M_M21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_M_MFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_M_MFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_M_MFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NAM_INDIA21AUG*.csv
# loading data from ./data/20210805/influxOP_NAM_INDIA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NAM_INDIA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NATIONALUM21AUG*.csv
# loading data from ./data/20210805/influxOP_NATIONALUM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NATIONALUM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NAUKRI21AUG*.csv
# loading data from ./data/20210805/influxOP_NAUKRI21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NAUKRI21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NAVINFLUOR21AUG*.csv
# loading data from ./data/20210805/influxOP_NAVINFLUOR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NAVINFLUOR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NESTLEIND21AUG*.csv
# loading data from ./data/20210805/influxOP_NESTLEIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NESTLEIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NMDC21AUG*.csv
# loading data from ./data/20210805/influxOP_NMDC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NMDC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_NTPC21AUG*.csv
# loading data from ./data/20210805/influxOP_NTPC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_NTPC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ONGC21AUG*.csv
# loading data from ./data/20210805/influxOP_ONGC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ONGC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PAGEIND21AUG*.csv
# loading data from ./data/20210805/influxOP_PAGEIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PAGEIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# skipped PAGEIND
# globbing ./data/*/*_PEL21AUG*.csv
# loading data from ./data/20210805/influxOP_PEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PETRONET21AUG*.csv
# loading data from ./data/20210805/influxOP_PETRONET21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PETRONET21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PFC21AUG*.csv
# loading data from ./data/20210805/influxOP_PFC21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PFC21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PFIZER21AUG*.csv
# loading data from ./data/20210805/influxOP_PFIZER21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PFIZER21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PIDILITIND21AUG*.csv
# loading data from ./data/20210805/influxOP_PIDILITIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PIDILITIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PIIND21AUG*.csv
# loading data from ./data/20210805/influxOP_PIIND21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PIIND21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PNB21AUG*.csv
# loading data from ./data/20210805/influxOP_PNB21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PNB21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_POWERGRID21AUG*.csv
# loading data from ./data/20210805/influxOP_POWERGRID21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_POWERGRID21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_PVR21AUG*.csv
# loading data from ./data/20210805/influxOP_PVR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_PVR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_RAMCOCEM21AUG*.csv
# loading data from ./data/20210805/influxOP_RAMCOCEM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_RAMCOCEM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_RBLBANK21AUG*.csv
# loading data from ./data/20210805/influxOP_RBLBANK21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_RBLBANK21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_RECLTD21AUG*.csv
# loading data from ./data/20210805/influxOP_RECLTD21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_RECLTD21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_RELIANCE21AUG*.csv
# loading data from ./data/20210805/influxOP_RELIANCE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_RELIANCE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SAIL21AUG*.csv
# loading data from ./data/20210805/influxOP_SAIL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SAIL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SBILIFE21AUG*.csv
# loading data from ./data/20210805/influxOP_SBILIFE21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SBILIFE21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SBIN21AUG*.csv
# loading data from ./data/20210805/influxOP_SBIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SBIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SHREECEM21AUG*.csv
# loading data from ./data/20210805/influxOP_SHREECEM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SHREECEM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SIEMENS21AUG*.csv
# loading data from ./data/20210805/influxOP_SIEMENS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SIEMENS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SRF21AUG*.csv
# loading data from ./data/20210805/influxOP_SRF21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SRF21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SRTRANSFIN21AUG*.csv
# loading data from ./data/20210805/influxOP_SRTRANSFIN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SRTRANSFIN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_STAR21AUG*.csv
# loading data from ./data/20210805/influxOP_STAR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_STAR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SUNPHARMA21AUG*.csv
# loading data from ./data/20210805/influxOP_SUNPHARMA21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SUNPHARMA21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_SUNTV21AUG*.csv
# loading data from ./data/20210805/influxOP_SUNTV21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_SUNTV21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TATACHEM21AUG*.csv
# loading data from ./data/20210805/influxOP_TATACHEM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TATACHEM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TATACONSUM21AUG*.csv
# loading data from ./data/20210805/influxOP_TATACONSUM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TATACONSUM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TATAMOTORS21AUG*.csv
# loading data from ./data/20210805/influxOP_TATAMOTORS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TATAMOTORS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TATAPOWER21AUG*.csv
# loading data from ./data/20210805/influxOP_TATAPOWER21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TATAPOWER21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TATASTEEL21AUG*.csv
# loading data from ./data/20210805/influxOP_TATASTEEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TATASTEEL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TCS21AUG*.csv
# loading data from ./data/20210805/influxOP_TCS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TCS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TECHM21AUG*.csv
# loading data from ./data/20210805/influxOP_TECHM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TECHM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TITAN21AUG*.csv
# loading data from ./data/20210805/influxOP_TITAN21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TITAN21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TORNTPHARM21AUG*.csv
# loading data from ./data/20210805/influxOP_TORNTPHARM21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TORNTPHARM21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TORNTPOWER21AUG*.csv
# loading data from ./data/20210805/influxOP_TORNTPOWER21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TORNTPOWER21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TRENT21AUG*.csv
# loading data from ./data/20210805/influxOP_TRENT21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TRENT21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_TVSMOTOR21AUG*.csv
# loading data from ./data/20210805/influxOP_TVSMOTOR21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_TVSMOTOR21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_UBL21AUG*.csv
# loading data from ./data/20210805/influxOP_UBL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_UBL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ULTRACEMCO21AUG*.csv
# loading data from ./data/20210805/influxOP_ULTRACEMCO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ULTRACEMCO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_UPL21AUG*.csv
# loading data from ./data/20210805/influxOP_UPL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_UPL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_VEDL21AUG*.csv
# loading data from ./data/20210805/influxOP_VEDL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_VEDL21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_VOLTAS21AUG*.csv
# loading data from ./data/20210805/influxOP_VOLTAS21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_VOLTAS21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_WIPRO21AUG*.csv
# loading data from ./data/20210805/influxOP_WIPRO21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_WIPRO21AUG_20210806.csv
# 2021-08-26 20:00:00
# globbing ./data/*/*_ZEEL21AUG*.csv
# loading data from ./data/20210805/influxOP_ZEEL21AUG_20210805.csv
# 2021-08-26 20:00:00
# loading data from ./data/20210806/influxOP_ZEEL21AUG_20210806.csv
# 2021-08-26 20:00:00

# %%
oc_pairs = ts.get_option_chain_pairs()

model_1 = IVPolynomial(2)
# model_2 = SVIModel()
model_2 = IVPolynomial(2, smoothening="kernel_smoothening")
model_3 = IVPolynomial(2, weighting="inverse_spread")
model_4 = IVPolynomial(2, weighting="vega")
model_5 = IVPolynomial(2, smoothening="kernel_smoothening", weighting="vega")
model_6 = IVPolynomial(2, smoothening="kernel_smoothening", weighting="inverse_spread")

models = [model_1, model_2, model_3, model_4, model_5, model_6]
# models = [model_1, model_2, model_3, model_4]

# %%
model_errors = get_errors_for_models(oc_pairs, models)

# %%
fig, axs = plt.subplots(1, 1)
fig.set_size_inches(12, 7)

for tickerwise_e, aggregated_e in model_errors:
    axs.hist(aggregated_e['ALL'], density=True, bins=20)
# axs.legend([f'model_{i+1}' for i in range(len(model_errors))])
axs.legend(['poly', 'poly + kernel'])

# %%
rows = []
for i, (tickerwise_e, aggregated_e) in enumerate(model_errors):
    row = {
        'model': f'model_{i+1}',
        'pricing_mae' : np.mean(np.abs(aggregated_e['ALL'])),
        'pricing_rmse' : np.sqrt(np.mean((aggregated_e['ALL'])**2)),
        'fit_mae' : np.mean(np.abs(np.array(aggregated_e['fit_errors']))),
        'fit_rmse' : np.sqrt(np.mean((np.array(aggregated_e['fit_errors']))**2)),
    } 
    rows.append(row)

df = pd.DataFrame(rows)

# %%
df
# Out:
#      model  pricing_mae  pricing_rmse   fit_mae  fit_rmse
# 0  model_1     0.130821      0.229066  0.013943  0.030458
# 1  model_2     0.098766      0.186705  0.016444  0.032478
# 2  model_3     0.109783      0.198029  0.014156  0.050049
# 3  model_4     0.143698      0.249450  0.015039  0.032604
# 4  model_5     0.106144      0.198048  0.015943  0.032542
# 5  model_6     0.099169      0.187025  0.016434  0.034197

# %%
df['model'] = ['poly', 'poly + kernel', 'poly + inv_spread', 'poly + vega', 'poly + kernel + inv_spread', 'poly + kernel + vega']

# %%
df
# Out:
#                         model  pricing_mae  pricing_rmse   fit_mae  fit_rmse
# 0                        poly     0.130821      0.229066  0.013943  0.030458
# 1               poly + kernel     0.098766      0.186705  0.016444  0.032478
# 2           poly + inv_spread     0.109783      0.198029  0.014156  0.050049
# 3                 poly + vega     0.143698      0.249450  0.015039  0.032604
# 4  poly + kernel + inv_spread     0.106144      0.198048  0.015943  0.032542
# 5        poly + kernel + vega     0.099169      0.187025  0.016434  0.034197

# %%
str(type(model2))
# Out:
# "<class 'iv_models.SVIModel'>"

# %%
oc_pairs['RELIANCE'][0].df

# %%
s = [1]
s.extend(np.array([2, 3]))
s

# %%
kernel_smoothening(oc_pairs['IDEA'][0])

# %%
oc_pairs
